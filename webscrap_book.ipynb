# %% [markdown]
# <a href="https://colab.research.google.com/github/budsayamasNithi/AI/blob/main/webscrap_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# เอาข้อมูลมาจากเว็บนี้
# https://www.facebook.com/watch/live/?v=537791520408332&ref=watch_permalink
#
# จะเขียน code นี้ต้องใช้ดังนี้
# 1. URL
# 2. urllib  ใช้การ request เพื่อดึงข้อมูลโดยไม่เปิด web browser
# 3. buetifulsoup4  เมื่อ request ได้แล้วจะแปลงข้อมูลให้เป็น html  โดยจะมี tag  ดังนั้นตัวนี้จะใช้ในการดึง element จาก html file
# 4. songline   เพื่อใช้ในการ songline ไปหาผู้ใช้

# %%
pip install beautifulsoup4

# %% [markdown]
# this code get libary from https://pypi.org  search  songline   author : Loong Wissawakorn (Uncle Engineer)

# %%
pip install songline
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for songline: filename=songline-0.0.2-py3-none-any.whl size=4868 sha256=8a90d558445309a72d9a3fb690912b72e1252385769abdcc3c0603f2aa927f9b
#   Stored in directory: /root/.cache/pip/wheels/b2/5c/85/9a7ba890449b322545ab4628d052b91155c6379b4f9a8669f4
# Successfully built songline
# ...

# %% [markdown]
# ทำการเรียกคำสั่งจาก libary ต่างๆ ที่เกี่ยวข้อง

# %%
from urllib.request import urlopen as req
from bs4 import BeautifulSoup as Soup

# %% [markdown]
# 2. Request URL by get data from url https://www.tmd.go.th/province.php?id=37

# %%
#url = 'https://www.tmd.go.th/province.php?id=37'
url = 'https://www.naiin.com/category?type_book=best_seller&product_type_id=1'
webopen = req(url)
page_html = webopen.read()
print(page_html) #report in term of bytes
webopen.close()
# Out:
# b'<!DOCTYPE html>\r\n<html xmlns:og="http://ogp.me/ns#" lang="th">\r\n\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta http-equiv="x-dns-prefetch-control" content="on">\r\n\r\n    <!-- CSRF Token -->\r\n    <meta name="csrf-token" content="NP5y0wo2KNO7oLFOivTgumH4yhUkg2PTu5TfxLFn">\r\n\r\n    <link rel=\'preconnect\' href=\'https://cdnjs.cloudflare.com\'/>\r\n    <!-- <link rel=\'preconnect\' href=\'https://connect.facebook.net\' /> -->\r\n\r\n    <link rel=\'preload\' href=\'https://fonts.gstatic.com/s/sarabun/v6/DtVmJx26TKEr37c9YNpoilss6w.woff2\' as="font" crossorigin />\r\n    <link rel=\'preload\' href=\'https://fonts.gstatic.com/s/sarabun/v6/DtVmJx26TKEr37c9YNpoik8s6zDX.woff2\' as="font" crossorigin />\r\n    <link rel=\'preload\' href=\'https://fonts.gstatic.com/s/sarabun/v6/DtVjJx26TKEr37c9aBVJnw.woff2\' as="font" crossorigin />\r\n    <link rel=\'preload\' href=\'https://fonts.gstatic.com/s/sarabun/v6/DtVjJx26T
# ...

# %%
#url = 'https://www.tmd.go.th/province.php?id=37'
#url = 'https://www.naiin.com/category?type_book=best_seller&product_type_id=1'
url = 'https://www.priceza.com/b/clothing-fashion-and-accessories/%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%97%E0%B9%89%E0%B8%B2%E0%B8%9C%E0%B9%89%E0%B8%B2%E0%B9%83%E0%B8%9A'
webopen = req(url)
page_html = webopen.read()
print(page_html) #report in term of bytes
webopen.close()
# Out:
# b'<!DOCTYPE html>\n<html xmlns:fb="http://ogp.me/ns/fb#" lang="th">\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# priceza: http://ogp.me/ns/fb/priceza#">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=3">\n\n<link rel="canonical" href="https://www.priceza.com/b/clothing-fashion-and-accessories/\xe0\xb8\xa3\xe0\xb8\xad\xe0\xb8\x87\xe0\xb9\x80\xe0\xb8\x97\xe0\xb9\x89\xe0\xb8\xb2\xe0\xb8\x9c\xe0\xb9\x89\xe0\xb8\xb2\xe0\xb9\x83\xe0\xb8\x9a" />\n\t<title>\xe0\xb8\xa3\xe0\xb8\xad\xe0\xb8\x87\xe0\xb9\x80\xe0\xb8\x97\xe0\xb9\x89\xe0\xb8\xb2\xe0\xb8\x9c\xe0\xb9\x89\xe0\xb8\xb2\xe0\xb9\x83\xe0\xb8\x9a \xe0\xb8\x97\xe0\xb8\xb8\xe0\xb8\x81\xe0\xb9\x81\xe0\xb8\x9a\xe0\xb8\xa3\xe0\xb8\x99\xe0\xb8\x94\xe0\xb9\x8c\xe0\xb8\x94\xe0\xb8\xb1\xe0\xb8\x87 \xe0\xb8\x97\xe0\xb8\xb8\xe0\xb8\x81\xe0\xb8\xa3\xe0\xb8\xb
# ...

# %% [markdown]
# 3 Convert page_html to Soup Object

# %%
#you must convert bytes to web_page using beutifulsoup
data = Soup(page_html,'html.parser')
print(data)
#หา tag ที่แสดงสินค้าและราคา
#หรือหาดูได้ที่ browser โดยคลิกขวาที่อุณภูมิแล้ว inspect ดู code
# Out:
# <!DOCTYPE html>
#
# <html lang="th" xmlns:fb="http://ogp.me/ns/fb#">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# priceza: http://ogp.me/ns/fb/priceza#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=3" name="viewport"/>
# <link href="https://www.priceza.com/b/clothing-fashion-and-accessories/รองเท้าผ้าใบ" rel="canonical"/>
# <title>รองเท้าผ้าใบ ทุกแบรนด์ดัง ทุกรุ่น เช็คราคาล่าสุดเดือนสิงหาคม 2566</title>
# <meta content="รองเท้าผ้าใบ อัพเดทราคาทุกยี่ห้อทุกรุ่น เทียบราคารองเท้าผ้าใบจากร้านค้าออนไลน์ทั่วไทย เช็คโปรชั่นและส่วนลดของเดือนสิงหาคม 2566 ก่อนใครได้ที่ Priceza.com " name="description">
# <meta content="รองเท้าผ้าใบ ทุกแบรนด์ดัง ทุกรุ่น เช็คราคาล่าสุดเดือนสิงหาคม 2566" property="og:title">
# ...

# %%
#you must convert bytes to web_page using beutifulsoup
data = Soup(page_html,'html.parser')
print(data)
#หา tag ที่แสดงสินค้าและราคา
#หรือหาดูได้ที่ browser โดยคลิกขวาที่อุณภูมิแล้ว inspect ดู code
# Out:
# <!DOCTYPE html>
#
# <html lang="th" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <!-- CSRF Token -->
# <meta content="mmYGJjvIP6QinGL35qsbnN3mtcETZfsJbLbCWit3" name="csrf-token"/>
# <link href="https://cdnjs.cloudflare.com" rel="preconnect"/>
# <!-- <link rel='preconnect' href='https://connect.facebook.net' /> -->
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sarabun/v6/DtVmJx26TKEr37c9YNpoilss6w.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sarabun/v6/DtVmJx26TKEr37c9YNpoik8s6zDX.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sarabun/v6/DtVjJx26TKEr37c9aBVJnw.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://fonts.gstatic.com/s/sarabun/v6/DtVjJx26TKEr37c9aAFJn2QN.woff2" rel="preload"/>
# ...

# %% [markdown]
# 4. Find Element tag p ('class: 'txt-price')

# %%
temp = data.findAll('p',{'class':'txt-price'})
print(temp)
#ค้นหาแท็กhtmlทั้งหมด(findAll)
# Out:
# [<p class="txt-price">212.50 บาท</p>, <p class="txt-price">88.00 บาท</p>, <p class="txt-price">242.25 บาท</p>, <p class="txt-price">246.50 บาท</p>, <p class="txt-price">208.25 บาท</p>, <p class="txt-price">88.00 บาท</p>, <p class="txt-price">255.55 บาท</p>, <p class="txt-price">113.00 บาท</p>, <p class="txt-price">98.00 บาท</p>, <p class="txt-price">113.00 บาท</p>, <p class="txt-price">191.25 บาท</p>, <p class="txt-price">391.00 บาท</p>, <p class="txt-price">118.00 บาท</p>, <p class="txt-price">225.25 บาท</p>, <p class="txt-price">221.00 บาท</p>, <p class="txt-price">128.00 บาท</p>, <p class="txt-price">148.75 บาท</p>, <p class="txt-price">279.65 บาท</p>, <p class="txt-price">113.00 บาท</p>, <p class="txt-price">225.25 บาท</p>, <p class="txt-price">335.75 บาท</p>, <p class="txt-price">238.00 บาท</p>, <p class="txt-price">284.05 บาท</p>, <p class="txt-price">238.00 บาท</p>, <p class="txt-price">238.00 บาท</p>, <p class="txt-price">238.00 บาท</p>, <p class="txt-price">357.00 บาท</p>, <
# ...

# %%
temp = data.findAll('div',{'class':'pz-pdb-price'})
print(temp)
# Out:
# [<div class="pz-pdb-price">
# <span content="THB">฿</span><span content="3213.0">3,213</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="3770.0">3,770</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1250.0">1,250</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1400.0">1,400</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1772.0">1,772</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1105.0">1,105</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1190.0">1,190</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="1494.5">1,494.50</span>
# </div>, <div class="pz-pdb-price">
# <span content="THB">฿</span><span content="222.3">222.30</span>
# <del class="pz-base-price">฿838</del>
# </div>, <div class="pz-pdb-price">
# ...

# %%
#ตัดคำให้เหลือแค่ราคา โดยใช้ .text เพื่อเอาแค่ข้อความอื่น ๆ ออก
result = temp[0].text
print(result)
# Out:
# ฿3,213

# %%
 #ดึงค่าชื่อหนังสือมาด้วย
 itemname = data.findAll('h3',{'class':'pz-pdb_name'})
 itn = itemname[1].text.replace(' ','') #ลบช่องว่างด้านหน้า
 print(itn)
 print('ชื่อรองเท้า : {} ราคา : {}'.format(itn,result)) #FORMAT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-dd007f09a4d0> in <cell line: 2>()
#       1 #ดึงค่าชื่อหนังสือมาด้วย
# ----> 2 itemname = data.findAll('h3',{'class':'pz-pdb_name'})
#       3 itn = itemname[1].text.replace(' ','') #ลบช่องว่างด้านหน้า
#       4 print(itn)
#       5 print('ชื่อรองเท้า : {} ราคา : {}'.format(itn,result)) #FORMAT
#
# AttributeError: 'Response' object has no attribute 'findAll'

# %%
#create function
def bestseller(itnid):
  url = 'https://www.priceza.com/b/clothing-fashion-and-accessories/%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%97%E0%B9%89%E0%B8%B2%E0%B8%9C%E0%B9%89%E0%B8%B2%E0%B9%83%E0%B8%9A'
  webopen = req(url)
  page_html = webopen.read()
  webopen.close()
  data = Soup(page_html,'html.parser')

  itemprice = data.findAll('div',{'class':'pz-pdb-price'})
  result = itemprice[itnid].text

  itemname = data.findAll('h3',{'class':'pz-pdb_name'})
  itn = itemname[itnid].text.replace(' ','')

  print('ชื่อรองเท้า : {} ราคา : {}'.format(itn,result))
  text = 'ชื่อรองเท้า : {} ราคา : {}'.format(itn,result)
  return  text

for i in range(0,10):
  bestseller(i)
# Out:
# ชื่อรองเท้า : Naturalizerรองเท้าผ้าใบรุ่นMarianne2.0NIC14 ราคา :
# ฿3,213
#
# ชื่อรองเท้า : Naturalizerรองเท้าSlipOnรุ่นPoppySeedNIS07 ราคา :
# ฿3,770
#
# ชื่อรองเท้า : AdidasCloudfoamPureWomenNEOShoes ราคา :
# ฿1,250
#
# ชื่อรองเท้า : AdidasCloudfoamSpeedWWomenNEOShoes ราคา :
# ฿1,400
#
# ชื่อรองเท้า : AdidasVSJogMenNEOShoes ราคา :
# ฿1,772
#
# ชื่อรองเท้า : FILADisruptor2Sneakers ราคา :
# ฿1,105
#
# ชื่อรองเท้า : NikeAirForce1'07Sneakers ราคา :
# ฿1,190
#
# ชื่อรองเท้า : AdidasNMDR1ShoesWomenOriginals ราคา :
# ฿1,494.50
#
# ชื่อรองเท้า : รองเท้าผ้าสไตล์ปักกิ่งแบบเก่ารองเท้าปักลายรองเท้าชั้นเดียวหัวกลมเสริมส้นด้านในพื้นยางTPRสไตล์จีนแบบฤดูใบไม้ร่วงสไตล์ชนเผ่ารองเท้าผู้หญิงแฟชั่น(12423437393) ราคา :
# ฿222.30
# ฿838
#
# ชื่อรองเท้า : CaspasSHOPZรองเท้าผู้ชายรองเท้าผ้าใบลดล้างสต๊อกราคาถูกสุด2020ใหม่ฤดูใบไม้ผลิของผู้ชายรองเท้าเวอร์ชั่นเกาหลีของแนวโน้มของป่าระบายอากาศในช่วงฤดูร้อนของผู้ชายรองเท้าลำลองรองเท้าผ้าใบรองเท้าชายน้ำ ราคา :
# ฿50
# ฿180

# %%
#create function
def bestseller(itnid):
  url = 'https://www.naiin.com/category?type_book=best_seller&product_type_id='
  webopen = req(url)
  page_html = webopen.read()
  webopen.close()
  data = Soup(page_html,'html.parser')

  itemprice = data.findAll('p',{'class':'txt-price'})
  result = itemprice[itnid].text

  itemname = data.findAll('a',{'class':'itemname'})
  itn = itemname[itnid].text.replace(' ','')

  print('ชื่อรองเท้า : {} ราคา : {}'.format(itn,result))
  text = 'ชื่อรองเท้า : {} ราคา : {}'.format(itn,result)
  return  text

for i in range(0,10):
  bestseller(i)
# Out:
# ชื่อรองเท้า : จิตวิทยาสายดาร์ก ราคา : 212.50 บาท
# ชื่อรองเท้า : เรื่องเล่าจากยอดภูเขาน้ำแข็ง(ปกใหม่) ราคา : 88.00 บาท
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-e25b834db403> in <cell line: 19>()
#      18
#      19 for i in range(0,10):
# ---> 20   bestseller(i)
#
# <ipython-input-30-e25b834db403> in bestseller(itnid)
#       2 def bestseller(itnid):
#       3   url = 'https://www.naiin.com/category?type_book=best_seller&product_type_id='
# ----> 4   webopen = req(url)
#       5   page_html = webopen.read()
#       6   webopen.close()
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# ...

# %%
#ดักจับ error กรณีที่ไม่มี field ที่ระบุไว้ หรือจังหวัดไม่มีข้อมูล
for i in range(25,35):
  try:
    bestseller(i)
  except Exception as e:
    print('no result because',e)
# Out:
# ชื่อรองเท้า : VansAnaheimFactoryOldSkool36DXSneakers ราคา :
# ฿2,350
#
# ชื่อรองเท้า : NikeAirForce1Mid'07Sneakers ราคา :
# ฿1,248
#
# ชื่อรองเท้า : PumaDareSlip-OnSneakers ราคา :
# ฿5,326
#
# ชื่อรองเท้า : NikeAirMax98Sneakers ราคา :
# ฿1,199
#
# ชื่อรองเท้า : AdidasTubularDoomSockPrimeknitOriginalsShoes ราคา :
# ฿1,949
#
# ชื่อรองเท้า : NikeAirMaxMotionSneakers ราคา :
# ฿1,200
#
# ชื่อรองเท้า : VansSK8-HISneakers ราคา :
# ฿1,274.90
#
# ชื่อรองเท้า : VansYachtClubOldSkoolSneakers ราคา :
# ฿790
#
# ชื่อรองเท้า : NikeSBBlazerLowXTSkateboardingShoes ราคา :
# ฿1,917
#
# ชื่อรองเท้า : NikeSBDunkLowProSkateboardingShoes ราคา :
# ฿1,164

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=c6721da4f85c7b4b55d4247bcbcf8562a70c486abc38bcdb7b4173c90d53e517
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
pip install requests

# %%
pip install pandas

# %%
pip install openpyxl

# %%
import pandas as pd
import bs4
import requests
import openpyxl

# %%
item = 1
name_list = []
price_list = []

while item <= 10:
  data = requests.get('https://www.priceza.com/b/clothing-fashion-and-accessories/%E0%B8%A3%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%97%E0%B9%89%E0%B8%B2%E0%B8%9C%E0%B9%89%E0%B8%B2%E0%B9%83%E0%B8%9A' )
  soup = bs4.BeautifulSoup(data.text)

  name = soup.find_all('h3',{'class':'pz-pdb_name'})
  price = soup.find_all('div',{'class':'pz-pdb-price'})

  for i in name:
    name_list.append(i.text)


  for i in price:
    price_list.append(i.text)

  print('Complete item number: ',item)
  item += 1

table = pd.DataFrame([name_list,price_list]).transpose()
table.columns = ['name','price']
table.set_index('name')
table.to_excel('all bestsellershose3.xlsx',engine='openpyxl') #file is created on google colab cloud
# Out:
# Complete item number:  1
# Complete item number:  2
# Complete item number:  3
# Complete item number:  4
# Complete item number:  5
# Complete item number:  6
# Complete item number:  7
# Complete item number:  8
# Complete item number:  9
# Complete item number:  10

# %%
#send data to line goto https://github.com/UncleEngineer/songline  click ออก token ในเว็บ: https://notify-bot.line.me/my/
#1 ออก token and login to line ต้องเข้าผ่าน web browser เท่านั้น
# u must use token        ปกติใช้ username + password ในการเข้า line แต่ในตัวline จะมี token แทน
#ตัว token จะแทน user password and group  ดังนั้นเวลาจะส่งเข้าไปใน line จะบอกว่าส่งไปให้ใครไป group ไหน  และ bot ชื่ออะไร
'''ไลบรารี่ใช้ส่งไลน์
ดาวโหลดตารางสติกเกอร์: http://cons-robotics.com/LINEAPI/sticker.pdf
ออก token ในเว็บ: https://notify-bot.line.me/my/
ดูวิธีการสร้าง line notify ได้ที่ https://www.smith.in.th/%E0%B8%AA%E0%B8%A3%E0%B9%89%E0%B8%B2%E0%B8%87-line-notify-%E0%B8%AA%E0%B8%B3%E0%B8%AB%E0%B8%A3%E0%B8%B1%E0%B8%9A-post-%E0%B8%A5%E0%B8%87%E0%B8%81%E0%B8%A5%E0%B8%B8%E0%B9%88%E0%B8%A1/
Log In ด้วยรหัสไลน์ -->
เลื่อนลงไปล่างสุดแล้วกด -->
กดปุ่ม generate token (ออก token)) -->
ตั้งชื่อ Bot -->
หากลุ่มที่ต้องการส่งแล้วคลิกให้ขึ้นอักษรสีเขียว -->
เพิ่มเพื่อนที่ชื่อ Line Notify เข้ากลุ่มด้วย -->'''
import songline
token = 'UlDzegZm6nlNAWp0u8RURUURFMBywzppklsyXTd8cKT'  #myjina  u must keep this no public u get from website bot.line.me/my
messenger = songline.Sendline(token)
messenger.sendtext('Hello')
# Out:
# <Response [200]>

# %%
#messenger.sendtext('hello this is code from python') # u must add line notify into your group
messenger.sticker(303,4)
# Out:
# <Response [200]>

# %%
messenger.sendimage('https://th.wikipedia.org/wiki/%E0%B8%AD%E0%B8%99%E0%B8%B8%E0%B8%97%E0%B8%B4%E0%B8%99_%E0%B8%8A%E0%B8%B2%E0%B8%8D%E0%B8%A7%E0%B8%B5%E0%B8%A3%E0%B8%81%E0%B8%B9%E0%B8%A5#/media/%E0%B9%84%E0%B8%9F%E0%B8%A5%E0%B9%8C:Anutin_Charnvirakul_-_2023_(52638148766)_(cropped).jpg')
# Out:
# <Response [200]>

# %%
import songline
#token = 'input your token'  #myjina  u must keep this no public u get from website bot.line.me/my
messenger = songline.Sendline(token)
book =  bestseller(25)
messenger.sendtext(book)
# Out:
# ชื่อหนังสือ : แอบรักให้เธอรู้เล่ม2 ราคา : 238.00 บาท
# <Response [200]>
